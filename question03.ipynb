# %%
from pandas import DataFrame
Data={"x":[6200,4500,8100,10000,8300,5600,2800,9700,3900,7400,6900,4400,9200,2500,5100,10000],"y":[820,590,630,1200,970,620,500,750,900,480,350,500,950,650,800,990]}
df=DataFrame(Data,columns=["x","y"])
print(df)
# Out:
#         x     y
# 0    6200   820
# 1    4500   590
# 2    8100   630
# 3   10000  1200
# 4    8300   970
# 5    5600   620
# 6    2800   500
# 7    9700   750
# 8    3900   900
# 9    7400   480
# 10   6900   350
# 11   4400   500
# 12   9200   950
# 13   2500   650
# 14   5100   800
# 15  10000   990

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

KMeans=KMeans(n_clusters=3).fit(df)
centroids =KMeans.cluster_centers_
print (centroids)
# Out:
# [[9216.66666667  915.        ]
#  [3620.          628.        ]
#  [6240.          614.        ]]

# %%
plt.scatter(df['x'],df['y'],c=KMeans.labels_.astype(float),s=50,alpha=0.5)

# %%
plt.scatter(centroids[:,0],centroids[:,1],c='red',s=50)

# %%
plt.scatter(df['x'],df['y'],c=KMeans.labels_.astype(float),s=50,alpha=0.5)
plt.scatter(centroids[:,0],centroids[:,1],c='red',s=50)
